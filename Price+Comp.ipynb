# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
URL_FK = f"https://www.flipkart.com/oppo-f19-pro-fluid-black-128-gb/p/itmf3153ba8dbf1a?pid=MOBGYV9VCE8G2SDV"

# %%
print(URL_FK)
# Out:
# https://www.flipkart.com/oppo-f19-pro-fluid-black-128-gb/p/itmf3153ba8dbf1a?pid=MOBGYV9VCE8G2SDV

# %%
URL_AZ = f"https://www.amazon.in/Fluid-Storage-Additional-Exchange-Offers/dp/B08V9VPCXW"

# %%
print(URL_AZ)
# Out:
# https://www.amazon.in/Fluid-Storage-Additional-Exchange-Offers/dp/B08V9VPCXW

# %%
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36"}

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
page_FK = requests.get(URL_FK, headers = header)

# %%
Soup1 = BeautifulSoup (page_FK.content, "html.parser")

# %%
print(Soup1)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(Soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.809fd9.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# ...

# %%
print(Soup1.title)
# Out:
# <title>OPPO F19 Pro ( 128 GB Storage, 8 GB RAM ) Online at Best Price On Flipkart.com</title>

# %%
print(Soup1.title.name)
# Out:
# title

# %%
print(Soup1.title.text)
# Out:
# OPPO F19 Pro ( 128 GB Storage, 8 GB RAM ) Online at Best Price On Flipkart.com

# %%
print(Soup1.title.string)
# Out:
# OPPO F19 Pro ( 128 GB Storage, 8 GB RAM ) Online at Best Price On Flipkart.com

# %%
#print(Soup1.title.parent)

# %%
print(Soup1.p)
# Out:
# <p>OPPO F19 Pro (Fluid Black, 128 GB) (8 GB RAM)</p>

# %%
print(Soup1.find('p'))
# Out:
# <p>OPPO F19 Pro (Fluid Black, 128 GB) (8 GB RAM)</p>

# %%
print(Soup1.find_all('p'))
# Out:
# [<p>OPPO F19 Pro (Fluid Black, 128 GB) (8 GB RAM)</p>, <p>The OPPO F19 Pro is a powerful smartphone with innovative camera technology to let you capture the beauty of any moment in all its glory. This smartphone comes with a 48 MP quadcam, AI Color Portrait Video, and Night Plus features to ensure that your photos and videos are truly breathtaking. Also, for a fast mobile-computing experience, it is powered by a MediaTek Helio P95 chip and 8 GB of RAM. <br/><br/></p>, <p>Make your nights fabulous and memorable with the OPPO F19 Pro.</p>, <p>The powerful 48 MP quadcam offers portrait-ready photography experience.</p>, <p>This feature ensures that your portrait videos stand out and look glamorous on your social media pages. This AI-powered software changes the background to black and white to make the subject of the video stand out with vibrant, vivid shades.</p>, <p>You can record both sides of a scene as this feature lets you capture a video using both the front and back cameras simu
# ...

# %%
for paragraph in Soup1.find_all('p'):
    print(paragraph.text)
# Out:
# OPPO F19 Pro (Fluid Black, 128 GB) (8 GB RAM)
# The OPPO F19 Pro is a powerful smartphone with innovative camera technology to let you capture the beauty of any moment in all its glory. This smartphone comes with a 48 MP quadcam, AI Color Portrait Video, and Night Plus features to ensure that your photos and videos are truly breathtaking. Also, for a fast mobile-computing experience, it is powered by a MediaTek Helio P95 chip and 8 GB of RAM.
# Make your nights fabulous and memorable with the OPPO F19 Pro.
# The powerful 48 MP quadcam offers portrait-ready photography experience.
# This feature ensures that your portrait videos stand out and look glamorous on your social media pages. This AI-powered software changes the background to black and white to make the subject of the video stand out with vibrant, vivid shades.
# You can record both sides of a scene as this feature lets you capture a video using both the front and back cameras simultaneously in split-screen mode.
# ...

# %%
Soup1.find_all('a')
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/oppo-f19-pro-fluid-black-128-gb/p/itmf3153ba8dbf1a%3Fpid%3DMOBGYV9VCE8G2SDV">Login</a>,
# ...

# %%
for links in Soup1.find_all('a'):
    print(links.get('href'))
# Out:
# /
# /plus
# /account/login?ret=/oppo-f19-pro-fluid-black-128-gb/p/itmf3153ba8dbf1a%3Fpid%3DMOBGYV9VCE8G2SDV
# /viewcart?otracker=Cart_Icon_Click
# /?otracker=product_breadCrumbs_Home
# /mobiles-accessories/pr?sid=tyy&marketplace=FLIPKART&otracker=product_breadCrumbs_Mobiles+%26+Accessories
# /mobiles/pr?sid=tyy,4io&marketplace=FLIPKART&otracker=product_breadCrumbs_Mobiles
# /mobiles/oppo~brand/pr?sid=tyy,4io&marketplace=FLIPKART&otracker=product_breadCrumbs_OPPO+Mobiles
# /oppo-f19-pro-crystal-silver-128-gb/p/itmf3153ba8dbf1a?pid=MOBGYV9VEMHYEQAA&lid=LSTMOBGYV9VEMHYEQAANMI9U7&marketplace=FLIPKART&sattr[]=color&sattr[]=storage&st=color
# /oppo-f19-pro-fantastic-purple-128-gb/p/itmf3153ba8dbf1a?pid=MOBGYV9VYYM5HJGK&lid=LSTMOBGYV9VYYM5HJGKKZMYVM&marketplace=FLIPKART&sattr[]=color&sattr[]=storage&st=color
# /oppo-f19-pro-fluid-black-128-gb/p/itmf3153ba8dbf1a?pid=MOBGYV9VCE8G2SDV&lid=LSTMOBGYV9VCE8G2SDVKROOXV&marketplace=FLIPKART&sattr[]=color&sattr[]=storage&st=color
# ...

# %%
fk_Price = Soup1.find(class_="_30jeq3 _16Jk6d")

# %%
print(fk_Price)
# Out:
# <div class="_30jeq3 _16Jk6d">₹21,990</div>

# %%
print(fk_Price.get_text())
# Out:
# ₹21,990

# %%
print(fk_Price.get_text().strip())
# Out:
# ₹21,990

# %%
print(fk_Price.get_text().strip()[1:])
# Out:
# 21,990

# %%
print(fk_Price.get_text().strip()[1:])
# Out:
# 21,990

# %%
page_FK = requests.get(URL_FK, headers = header)

# %%
page_AZ = requests.get(URL_AZ , headers = header)

# %%
Soup2 = BeautifulSoup (page_AZ.content , 'html.parser')

# %%
print(Soup2.title)
# Out:
# <title>OPPO F19 Pro (Fluid Black, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers : Amazon.in: Electronics</title>

# %%
print(Soup2.title.text)
# Out:
# OPPO F19 Pro (Fluid Black, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers : Amazon.in: Electronics

# %%
az_Price = Soup2.find(id ="priceblock_dealprice")

# %%
print(az_Price)
# Out:
# <span class="a-size-medium a-color-price priceBlockDealPriceString" id="priceblock_dealprice">₹21,490.00</span>

# %%
print(az_Price.get_text())
# Out:
# ₹21,490.00

# %%
print(az_Price.get_text().strip())
# Out:
# ₹21,490.00

# %%
print(az_Price.get_text().strip()[1:])
# Out:
# 21,490.00

# %%
azPrice = az_Price.get_text().strip()[1:]
fkPrice = fk_Price.get_text().strip()[1:]

# %%
#azPrice = int(azPrice)

# %%
azPrice = float(azPrice.replace(',',''))

# %%
print(azPrice)
# Out:
# 21490.0

# %%
fkPrice = float(fkPrice.replace(',',''))

# %%
print(fkPrice)
# Out:
# 21990.0

# %%
Bestprice =0
Website = ''

if (fkPrice<azPrice):
    Bestprice = fkPrice
    Website = URL_FK
else:
    Bestprice = azPrice
    Website = URL_AZ

# %%
print ('Buy from ', Website , ' at ' , Bestprice)
# Out:
# Buy from  https://www.amazon.in/Fluid-Storage-Additional-Exchange-Offers/dp/B08V9VPCXW  at  21490.0
